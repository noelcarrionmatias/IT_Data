# %% [markdown]
# 1. Carrega el següent (hospital.csv) fitxer amb aquesta instrucció:
#
# data = pd.read_csv("arxiu csv", sep = ";", encoding = "latin-1")

# %%
import pandas as pd
data = pd.read_csv("hospitals.csv", sep=";", encoding="ISO-8859-1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' from 'C:\Users\noel_\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\__init__.py' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       2 data = pd.read_csv("hospitals.csv", sep=";", encoding="ISO-8859-1")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\__init__.py:58
#      55 # let init-time option registration happen
# ...
